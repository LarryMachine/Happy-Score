# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

data15=pd.read_csv(r"C:\Users\Administrator\Downloads\2015.csv")
data16=pd.read_csv(r"C:\Users\Administrator\Downloads\2016.csv")
data15


datay=['Country','Region','Happiness Rank','Happiness Score','Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']
datax=data15[datay]


rr=['Country','Region','Happiness Rank','Happiness Score','Lower Confidence Interval','Upper Confidence Interval','Economy (GDP per Capita)','Family',
    'Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']
ss=data16[rr]
ss
ff=[ss,datax]
concatinate=pd.concat(ff,sort=True)
concatinate
remove=concatinate.drop("Standard Error",axis=1)
remove
xl=plt.xlabel("Happiness_Rank")
yl=plt.ylabel("Happiness_Score")
title=plt.title("Rank vs Score")
#color=plt.color("green")
dd=plt.scatter(x=remove["Happiness Rank"],y=remove["Happiness Score"],marker='x')
#happy=plt.Heatmap()

ty=plt.show()
corr_matrix=remove.corr()
yl=sns.heatmap(corr_matrix, annot=False,cmap="coolwarm",fmt="0.2f")
plt.title("Correlation Matrix Heatmap")
plt.show()
